# %% [markdown]
# # In-Class Exercise: Decision Trees for Classification
#
# **Course:** ECON6083 - Machine Learning in Economics
# **Topic:** Decision Trees & Ensemble Methods
# **Time:** 25 minutes

# %% [markdown]
# ## Objective
#
# To understand how a decision tree makes predictions
# and how ensemble methods like Random Forest can
# improve performance. We focus on a classification task.

# %% [markdown]
# ## Scenario: Predicting Loan Default
#
# We have a dataset of loan applicants and want to predict whether a loan will default.
#
# -   **Outcome (Y):** `Default` (1 if defaulted, 0 otherwise)
# -   **Features (X):** `Income` (annual income), `Credit_Score`

# %% [markdown]
# ## Part I: Conceptual Understanding (10 minutes)
#
# 1. **Decision Boundaries:** How does a decision tree split
#    the feature space to make predictions?
#    Are the decision boundaries linear or non-linear?
#
#    **Your Answer:** ____

# %% [markdown]
# 2. **Gini Impurity:** What does the Gini impurity measure?
#    How does a decision tree use it to decide on the best split?
#
#    **Your Answer:** ____

# %% [markdown]
# 3. **Entropy vs. Gini:** Both entropy and Gini impurity can be used
#    as criteria for splitting. Briefly describe the difference between them.
#    In practice, do they usually lead to very different trees?
#
#    **Your Answer:** ____

# %% [markdown]
# 4. **Overfitting & Pruning:** What happens to a decision tree as
#    you allow it to grow deeper (increase `max_depth`)?
#    How does limiting `max_depth` act as a form of pruning?
#
#    **Your Answer:** ____

# %% [markdown]
# 5. **Random Forests:** What are the two main sources of
#    randomness in a Random Forest? How do these help
#    to reduce overfitting compared to a single decision tree?
#
#    **Your Answer:** ____

# %% [markdown]
# ## Part II: Python Implementation (15 minutes)
#
# Let's use `scikit-learn` to build a decision tree,
# visualize it, tune its depth, and compare it to a random forest.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Step 1: Load the data
#
# Create a small loan default dataset and split
# into training and test sets.

# %%
data = {
    'Income': [50, 80, 120, 40, 60, 200, 30, 90, 150, 70],
    'Credit_Score': [550, 700, 750, 500, 650, 800, 600, 720, 780, 680],
    'Default': [1, 0, 0, 1, 1, 0, 1, 0, 0, 1]
}
df = pd.DataFrame(data)
df.head()

# %% [markdown]
# ### Step 1b: Prepare features and split
#
# Separate features (X) and target (y), then create
# training and test sets.

# %%
X = df[['Income', 'Credit_Score']]
y = df['Default']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %% [markdown]
# ### Step 2: Fit a single Decision Tree
#
# Fit a `DecisionTreeClassifier` and calculate the test accuracy.

# %%
tree = DecisionTreeClassifier(max_depth=____)  # TODO: Set max_depth to 2
tree.____(X_train, y_train)  # TODO: Fit the model on the training data

tree_pred = tree.predict(X_test)
tree_acc = ____(y_test, tree_pred)  # TODO: Compute classification accuracy

print(f"Decision Tree Test Accuracy: {tree_acc:.2f}")

# %% [markdown]
# ### Step 3: Visualize the tree
#
# Visualize the fitted decision tree to see how it splits
# on `Income` and `Credit_Score`.

# %%
plt.figure(figsize=(12, 6))
____(tree, feature_names=X.columns, class_names=['No Default', 'Default'],
     filled=True, rounded=True)  # TODO: Plot the fitted decision tree
plt.show()

# %% [markdown]
# ### Step 4: Tune `max_depth`
#
# Try different values of `max_depth` to see how tree depth
# affects test accuracy.

# %%
depths = [1, 2, 3, 4, 5]
test_accuracies = []

for d in depths:
    t = DecisionTreeClassifier(max_depth=d)
    t.fit(X_train, y_train)
    test_accuracies.append(____)  # TODO: Compute test accuracy for this depth

for d, acc in zip(depths, test_accuracies):
    print(f"max_depth={d}: Test Accuracy = {acc:.2f}")

# %% [markdown]
# ### Step 5: Fit a Random Forest
#
# Fit a `RandomForestClassifier` with
# `n_estimators=100` and `max_depth=2`,
# then calculate the test accuracy.

# %%
forest = ____(n_estimators=100, max_depth=2)  # TODO: Initialize RandomForestClassifier
forest.____(X_train, y_train)  # TODO: Fit the ensemble on training data

forest_pred = forest.predict(X_test)
forest_acc = accuracy_score(y_test, forest_pred)

print(f"Random Forest Test Accuracy: {forest_acc:.2f}")

# %% [markdown]
# ### Questions to Discuss
#
# - Which model performed better?

# %% [markdown]
# - If you increase the `max_depth` of the single decision tree,
#   what do you expect to happen to the training accuracy?
#   What about the test accuracy?

# %% [markdown]
# - How does the Random Forest combine the predictions
#   of the individual trees?
